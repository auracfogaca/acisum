# %% [markdown]
# <a href="https://colab.research.google.com/github/auracfogaca/acisum/blob/main/notebooks/Module2-MIT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Colab is making it easier than ever to integrate powerful Generative AI capabilities into your projects. We are launching public preview for a simple and intuitive Python library (google.colab.ai) to access state-of-the-art language models directly within Colab environments. All users have free access to most popular LLMs, while paid users have access to a wider selection of models. This means users can spend less time on configuration and set up and more time bringing their ideas to life. With just a few lines of code, you can now perform a variety of tasks:
# - Generate text
# - Translate languages
# - Write creative content
# - Categorize text
#
# Happy Coding!
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb)

# %%
# @title List available models
from google.colab import ai

ai.list_models()
# Out:
# ['google/gemini-2.5-flash', 'google/gemini-2.5-flash-lite']

# %% [markdown]
# Choosing a Model
# The model names give you a hint about their capabilities and intended use:
#
# Pro: These are the most capable models, ideal for complex reasoning, creative tasks, and detailed analysis.
#
# Flash: These models are optimized for high speed and efficiency, making them great for summarization, chat applications, and tasks requiring rapid responses.
#
# Gemma: These are lightweight, open-weight models suitable for a variety of text generation tasks and are great for experimentation.

# %%
# @title Simple batch generation example
# Only text-to-text input/output is supported
from google.colab import ai

response = ai.generate_text("What is the capital of France?")
print(response)
# Out:
# The capital of France is **Paris**.

# %%
# @title Choose a different model
from /tmp/ipython-input-1810143207.py import ai

response = ai.generate_text("What is the capital of England", model_name='google/gemini-2.0-flash-lite')
print(response)
# Out:
#   File "/tmp/ipython-input-1682957619.py", line 2
#     from /tmp/ipython-input-1810143207.py import ai
#                                       ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# For longer text generations, you can stream the response. This displays the output token by token as it's generated, rather than waiting for the entire response to complete. This provides a more interactive and responsive experience. To enable this, simply set stream=True.

# %%
# @title Simple streaming example
from google.colab import ai

stream = ai.generate_text("Tell me a short story.", stream=True)
for text in stream:
  print(text, end='')
# Out:
# Elias lived in the quiet hum of forgotten things. His workshop, nestled in the attic of a stoic Victorian house, was a mausoleum of half-finished projects, intricate gears, and the faint, sweet scent of aged wood. Once, his hands had danced with purpose, coaxing life from inert materials, but now they trembled slightly, mostly still. He was a clockmaker by trade, a creator of delicate mechanisms, but time, it seemed, had begun to unwind him.
#
# One particularly grey afternoon, a shard of weak sunlight pierced a dusty windowpane, illuminating a corner Elias hadn't visited in decades. Tucked beneath a forgotten canvas drop cloth, he found it: a small, unassuming music box he’d started building in his youth. It was carved from dark, polished mahogany, inlaid with mother-of-pearl, but unfinished. Its winding key was missing, its delicate teeth silent.
#
# A strange compulsion stirred in him. He cleared the dust, revealing the intricate, empty space where the mechanism should have been. It wasn't the ticking of a clock that called to him now, but the potential for melody. Over the next few days, Elias found himself meticulously crafting the missing pieces. His fingers, stiff with age, slowly rediscovered their old agility. He filed, he polished, he assembled, each tiny gear a testament to a forgotten skill.
#
# Finally, with a gentle click, the last component slipped into place. He turned the newly crafted key, a breath held in his chest. A low, uncertain whirring began, followed by a tentative, almost shy, melody.
#
# It wasn't a tune he recognized. It was a simple, looping sequence of notes, delicate as a spider's silk. But as it played, something remarkable happened. The dust motes dancing in the sunlight seemed to shimmer with greater intensity, and Elias felt a peculiar lightness in his own chest.
#
# He re-wound the key. The melody played again, and this time, he saw it. Not with his eyes, but with a vivid clarity in his mind: a young woman, her hair the color of spun moonlight, laughing in a field of wildflowers. He hadn't thought of her in fifty years, not since she’d left their small town for the city lights.
#
# With each replay, the music seemed to deepen, to draw forth more. The laughter grew clearer, the scent of wildflowers almost tangible. He saw the way the light caught her smile, heard the distant buzz of bees. The music box wasn't just playing a tune; it was playing *memories*. Not just his, but perhaps the memories embedded in the wood itself, the echoes of lives that had brushed against its silent form.
#
# Elias spent the rest of the afternoon, and then many days after, listening. The music box played the innocent joy of children long grown old, the tender whispers of lovers under moonlit skies, the quiet resilience of countless moments that had unfolded in the very house around him. Each note was a thread, weaving an tapestry of time.
#
# His hands, once weary, now busied themselves again, not with clocks, but with new ideas. He began to sketch designs for other musical contraptions, instruments that might not just play tunes, but evoke feelings, stories, the very soul of a place. The dust in his workshop still danced in the sunlight, but now it danced to a melody – a melody of remembrance, of possibility, and of a life, once thought wound down, quietly starting to tick again.

# %%
#@title Text formatting setup
#code is not necessary for colab.ai, but is useful in fomatting text chunks
import sys

class LineWrapper:
    def __init__(self, max_length=80):
        self.max_length = max_length
        self.current_line_length = 0

    def print(self, text_chunk):
        i = 0
        n = len(text_chunk)
        while i < n:
            start_index = i
            while i < n and text_chunk[i] not in ' \n': # Find end of word
                i += 1
            current_word = text_chunk[start_index:i]

            delimiter = ""
            if i < n: # If not end of chunk, we found a delimiter
                delimiter = text_chunk[i]
                i += 1 # Consume delimiter

            if current_word:
                needs_leading_space = (self.current_line_length > 0)

                # Case 1: Word itself is too long for a line (must be broken)
                if len(current_word) > self.max_length:
                    if needs_leading_space: # Newline if current line has content
                        sys.stdout.write('\n')
                        self.current_line_length = 0
                    for char_val in current_word: # Break the long word
                        if self.current_line_length >= self.max_length:
                            sys.stdout.write('\n')
                            self.current_line_length = 0
                        sys.stdout.write(char_val)
                        self.current_line_length += 1
                # Case 2: Word doesn't fit on current line (print on new line)
                elif self.current_line_length + (1 if needs_leading_space else 0) + len(current_word) > self.max_length:
                    sys.stdout.write('\n')
                    sys.stdout.write(current_word)
                    self.current_line_length = len(current_word)
                # Case 3: Word fits on current line
                else:
                    if needs_leading_space:
                        # Define punctuation that should not have a leading space
                        # when they form an entire "word" (token) following another word.
                        no_leading_space_punctuation = {
                            ",", ".", ";", ":", "!", "?",        # Standard sentence punctuation
                            ")", "]", "}",                     # Closing brackets
                            "'s", "'S", "'re", "'RE", "'ve", "'VE", # Common contractions
                            "'m", "'M", "'ll", "'LL", "'d", "'D",
                            "n't", "N'T",
                            "...", "…"                          # Ellipses
                        }
                        if current_word not in no_leading_space_punctuation:
                            sys.stdout.write(' ')
                            self.current_line_length += 1
                    sys.stdout.write(current_word)
                    self.current_line_length += len(current_word)

            if delimiter == '\n':
                sys.stdout.write('\n')
                self.current_line_length = 0
            elif delimiter == ' ':
                # If line is full and a space delimiter arrives, it implies a wrap.
                if self.current_line_length >= self.max_length:
                    sys.stdout.write('\n')
                    self.current_line_length = 0

        sys.stdout.flush()

# %%
# @title Formatted streaming example
from google.colab import ai

wrapper = LineWrapper()
for chunk in ai.generate_text('Give me a long winded description about the evolution of the Roman Empire.', model_name='google/gemini-2.0-flash', stream=True):
  wrapper.print(chunk)
